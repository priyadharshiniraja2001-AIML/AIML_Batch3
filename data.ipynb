# %%
print("Hii")
# Out:
# Hii

# %%
! pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.5.1-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.5.1-cp313-cp313-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.4 MB 1.3 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/12.4 MB 1.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/12.4 MB 1.5 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/12.4 MB 1.5 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.4 MB 1.6 MB/s eta 0:00:07
#    -------- ------------------------------- 2.6/12.4 MB 1.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.1/12.4 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.7/12.4 MB 1.9 MB/s eta 0:00:05
#    ------------- -------------------------- 4.2/12.4 MB 2.0 MB/s eta 0:00:05
#    --------------- ------------------------ 4.7/12.4 MB 2.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.5/12.4 MB 2.2 MB/s eta 0:00:04
#    -------------------- ------------------- 6.3/12.4 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.1/12.4 MB 2.5 MB/s eta 0:00:03
#    ------------------------- -------------- 7.9/12.4 MB 2.5 MB/s eta 0:00:02
#    --------------------------- ------------ 8.7/12.4 MB 2.6 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.4 MB 2.7 MB/s eta 0:00:02
#    --------------------------------- ------ 10.5/12.4 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.4 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.4 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 2.9 MB/s  0:00:04
# Installing collected packages: numpy
# Successfully installed numpy-2.5.1

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in d:\AIMl\.venv-1\Lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\AIMl\.venv-1\Lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\AIMl\.venv-1\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.8 MB 1.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.8 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.8 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.4/9.8 MB 1.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.9/9.8 MB 2.0 MB/s eta 0:00:04
#    --------------- ------------------------ 3.7/9.8 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.8 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 5.2/9.8 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.8 MB 2.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.1/9.8 MB 2.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 3.2 MB/s  0:00:03
# Downloading tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, pandas
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed pandas-3.0.3 tzdata-2026.3

# %%
import numpy as np
marks = np.random.randint(35,101,50)
print(marks)
# Out:
# [92 75 98 53 91 75 81 97 76 73 94 95 60 66 88 82 48 38 53 90 47 78 61 95
#  35 72 75 99 49 99 45 87 84 35 84 40 88 99 46 66 42 61 77 97 67 70 47 76
#  52 96]

# %%
print(np.mean(marks))
print(np.median(marks))
print(np.std(marks))
# Out:
# 71.88
# 75.0
# 19.914457060135984

# %%
! pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.18.0-cp313-cp313-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.8,>=2.0.0 in d:\AIMl\.venv-1\Lib\site-packages (from scipy) (2.5.1)
# Downloading scipy-1.18.0-cp313-cp313-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.6 MB ? eta -:--:--
#     --------------------------------------- 0.5/36.6 MB 1.5 MB/s eta 0:00:25
#    - -------------------------------------- 1.0/36.6 MB 2.0 MB/s eta 0:00:19
#    - -------------------------------------- 1.6/36.6 MB 2.0 MB/s eta 0:00:18
#    -- ------------------------------------- 1.8/36.6 MB 2.0 MB/s eta 0:00:18
#    -- ------------------------------------- 2.4/36.6 MB 2.2 MB/s eta 0:00:16
#    --- ------------------------------------ 2.9/36.6 MB 2.2 MB/s eta 0:00:16
#    ---- ----------------------------------- 3.7/36.6 MB 2.4 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.5/36.6 MB 2.5 MB/s eta 0:00:13
#    ----- ---------------------------------- 5.2/36.6 MB 2.6 MB/s eta 0:00:12
#    ------ --------------------------------- 5.8/36.6 MB 2.7 MB/s eta 0:00:12
#    ------- -------------------------------- 6.6/36.6 MB 2.7 MB/s eta 0:00:11
#    -------- ------------------------------- 7.3/36.6 MB 2.8 MB/s eta 0:00:11
#    -------- ------------------------------- 7.9/36.6 MB 2.8 MB/s eta 0:00:11
#    --------- ------------------------------ 8.4/36.6 MB 2.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 9.4/36.6 MB 2.9 MB/s eta 0:00:10
#    ----------- ---------------------------- 10.2/36.6 MB 3.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 10.7/36.6 MB 3.0 MB/s eta 0:00:09
#    ------------ --------------------------- 11.3/36.6 MB 2.9 MB/s eta 0:00:09
#    ------------ --------------------------- 11.5/36.6 MB 2.8 MB/s eta 0:00:09
#    ------------- -------------------------- 12.3/36.6 MB 2.9 MB/s eta 0:00:09
#    -------------- ------------------------- 12.8/36.6 MB 2.9 MB/s eta 0:00:09
#    --------------- ------------------------ 13.9/36.6 MB 2.9 MB/s eta 0:00:08
#    --------------- ------------------------ 14.4/36.6 MB 2.9 MB/s eta 0:00:08
#    ---------------- ----------------------- 14.7/36.6 MB 2.9 MB/s eta 0:00:08
#    ---------------- ----------------------- 15.2/36.6 MB 2.9 MB/s eta 0:00:08
#    ----------------- ---------------------- 15.7/36.6 MB 2.8 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.3/36.6 MB 2.8 MB/s eta 0:00:08
#    ------------------ --------------------- 16.8/36.6 MB 2.8 MB/s eta 0:00:07
#    ------------------ --------------------- 17.3/36.6 MB 2.8 MB/s eta 0:00:07
#    ------------------- -------------------- 17.6/36.6 MB 2.8 MB/s eta 0:00:07
#    -------------------- ------------------- 18.4/36.6 MB 2.8 MB/s eta 0:00:07
#    -------------------- ------------------- 18.6/36.6 MB 2.8 MB/s eta 0:00:07
#    -------------------- ------------------- 19.1/36.6 MB 2.7 MB/s eta 0:00:07
#    --------------------- ------------------ 19.4/36.6 MB 2.7 MB/s eta 0:00:07
#    --------------------- ------------------ 19.9/36.6 MB 2.7 MB/s eta 0:00:07
#    ---------------------- ----------------- 20.4/36.6 MB 2.7 MB/s eta 0:00:06
#    ---------------------- ----------------- 21.0/36.6 MB 2.7 MB/s eta 0:00:06
#    ----------------------- ---------------- 21.2/36.6 MB 2.7 MB/s eta 0:00:06
#    ------------------------ --------------- 22.3/36.6 MB 2.7 MB/s eta 0:00:06
#    ------------------------ --------------- 22.8/36.6 MB 2.7 MB/s eta 0:00:06
#    ------------------------- -------------- 23.6/36.6 MB 2.7 MB/s eta 0:00:05
#    -------------------------- ------------- 23.9/36.6 MB 2.7 MB/s eta 0:00:05
#    -------------------------- ------------- 24.6/36.6 MB 2.7 MB/s eta 0:00:05
#    ---------------------------- ----------- 25.7/36.6 MB 2.8 MB/s eta 0:00:04
#    ----------------------------- ---------- 27.0/36.6 MB 2.8 MB/s eta 0:00:04
#    ------------------------------ --------- 28.0/36.6 MB 2.9 MB/s eta 0:00:03
#    ------------------------------- -------- 29.1/36.6 MB 2.9 MB/s eta 0:00:03
#    -------------------------------- ------- 30.1/36.6 MB 3.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.2/36.6 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.2/36.6 MB 3.1 MB/s eta 0:00:02
#    ------------------------------------ --- 33.6/36.6 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 34.3/36.6 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 35.1/36.6 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.6 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 3.2 MB/s  0:00:11
# Installing collected packages: scipy
# Successfully installed scipy-1.18.0

# %%
! pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\AIMl\.venv-1\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 675.9 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/9.3 MB 789.3 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/9.3 MB 789.3 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.0/9.3 MB 718.2 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.3 MB 785.7 kB/s eta 0:00:11
#    ------ --------------------------------- 1.6/9.3 MB 835.6 kB/s eta 0:00:10
#    ------- -------------------------------- 1.8/9.3 MB 934.5 kB/s eta 0:00:09
#    ---------- ----------------------------- 2.4/9.3 MB 1.1 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.4/9.3 MB 1.1 MB/s eta 0:00:07
#    ------------ --------------------------- 2.9/9.3 MB 1.1 MB/s eta 0:00:06
#    -------------- ------------------------- 3.4/9.3 MB 1.2 MB/s eta 0:00:05
#    -------------- ------------------------- 3.4/9.3 MB 1.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.9/9.3 MB 1.2 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.3 MB 1.2 MB/s eta 0:00:05
#    ------------------- -------------------- 4.5/9.3 MB 1.2 MB/s eta 0:00:04
#    -------------------- ------------------- 4.7/9.3 MB 1.3 MB/s eta 0:00:04
#    --------------------- ------------------ 5.0/9.3 MB 1.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.2/9.3 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.2/9.3 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.2/9.3 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.5/9.3 MB 1.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.5/9.3 MB 1.2 MB/s eta 0:00:04
#    ------------------------ --------------- 5.8/9.3 MB 1.1 MB/s eta 0:00:04
#    ------------------------- -------------- 6.0/9.3 MB 1.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 6.6/9.3 MB 1.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 6.6/9.3 MB 1.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 6.8/9.3 MB 1.1 MB/s eta 0:00:03
#    ------------------------------- -------- 7.3/9.3 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 7.6/9.3 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.1/9.3 MB 1.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.3 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 1.2 MB/s  0:00:09
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.3 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/7.2 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.2 MB 3.1 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.2 MB 3.7 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 5.8/7.2 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 3.7 MB/s  0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pillow-12.3.0 pyparsing-3.3.2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
x = np.linspace(-4,4,100)
y = norm.pdf(x)
plt.plot(x,y)
plt.title("Normal Distribution")
plt.xlabel("X Values")
plt.ylabel("Probability Density")
plt.show()

# %% [markdown]
# # Task
# count students in a range
# generate marks for 500 students
# # Observation
# number of students scoring between 60-80
# number of students scoring above 90
# number of students scoring below 50

# %% [markdown]
# # Correlation
# # 17.07.2026

# %%
! pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\AIMl\.venv-1\Lib\site-packages (from seaborn) (2.5.1)
# Requirement already satisfied: pandas>=1.2 in d:\AIMl\.venv-1\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\AIMl\.venv-1\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\AIMl\.venv-1\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\AIMl\.venv-1\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in d:\AIMl\.venv-1\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("diamonds")
print(df.head())
numeric_df = df.select_dtypes(include = ['number'])
corr = numeric_df.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt = ".2f")
plt.title("Correlation Matrix -Dimond Dataset")
plt.show()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import numpy as np
marks = np.array([80,85,90,95,100])
print(marks)
print(marks[2])
print(marks.mean())
print(marks.max())
print(marks.min())
# Out:
# [ 80  85  90  95 100]
# 90
# 90.0
# 100
# 80

# %%
students = np.array([
    [80,75,90],
    [65,58,88],
    [92,95,96]
])
print(students.shape)
print(students[1])
print(students[:,1])
# Out:
# (3, 3)
# [65 58 88]
# [75 58 95]

# %% [markdown]
# # Indexing & Slicing
# # 18.07.2026

# %%
import numpy as np
arr = np.array([10,20,30,40,50,60])
print(arr)
print(arr[3])
print(arr[2:4])
print(arr[-1])
print(arr[-4:-2])
print(arr[::-1])
# Out:
# [10 20 30 40 50 60]
# 40
# [30 40]
# 60
# [30 40]
# [60 50 40 30 20 10]

# %%
arr = np.array([
    [10,20,30],
    [40,50,60],
    [70,80,90]
])
print(arr)
print(arr[1,1])
print(arr[2,2])
print(arr[:,0])
print(arr[:2,:])
print(arr[1:,1:])
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 80 90]]
# 50
# 90
# [10 40 70]
# [[10 20 30]
#  [40 50 60]]
# [[50 60]
#  [80 90]]

# %%
import numpy as np
import pandas as pd
np.random.seed(42)
rows = 1000

df = pd.DataFrame({
"Student_ID": range(1, rows + 1),
"Age": np.random.randint(18, 26, rows),
"Study_Hours": np.random.randint(1, 11, rows),
"Attendance": np.random.randint(60, 101, rows),
"Assignments": np.random.randint(1, 11, rows),
"Previous_Marks": np.random.randint(40, 101, rows),
"Sleep_Hours": np.random.randint(4, 10, rows),
"Internet_Usage": np.random.randint(1, 9, rows),
"Marks": np.random.randint(35, 101, rows)
})
print(df.head())
df.to_csv("student_performance_1000.csv", index=False)
# Out:
#    Student_ID  Age  Study_Hours  Attendance  Assignments  Previous_Marks  \
# 0           1   24            6          98           10              84
# 1           2   21            1          61            3              80
# 2           3   22            9          97            3              68
# 3           4   24            1          98            1              43
# 4           5   20            5          85            7              44
#
#    Sleep_Hours  Internet_Usage  Marks
# 0            9               6     54
# 1            4               8     89
# 2            9               5     36
# 3            6               6     59
# 4            8               1     47

# %%
print(df)
# Out:
#      Student_ID  Age  Study_Hours  Attendance  Assignments  Previous_Marks  \
# 0             1   24            6          98           10              84
# 1             2   21            1          61            3              80
# 2             3   22            9          97            3              68
# 3             4   24            1          98            1              43
# 4             5   20            5          85            7              44
# ..          ...  ...          ...         ...          ...             ...
# 995         996   22            9          81            1              44
# 996         997   18            1          71            1              99
# 997         998   21            4          83            6              95
# 998         999   25           10          99            2              85
# 999        1000   20            6          97            8              89
#
#      Sleep_Hours  Internet_Usage  Marks
# 0              9               6     54
# 1              4               8     89
# 2              9               5     36
# 3              6               6     59
# 4              8               1     47
# ..           ...             ...    ...
# 995            8               7     85
# 996            4               7     73
# 997            9               1     38
# 998            5               7     37
# 999            8               2     98
#
# [1000 rows x 9 columns]

# %%
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)
print(df.info())
print(df.describe())
# Out:
#    Student_ID  Age  Study_Hours  Attendance  Assignments  Previous_Marks  \
# 0           1   24            6          98           10              84
# 1           2   21            1          61            3              80
# 2           3   22            9          97            3              68
# 3           4   24            1          98            1              43
# 4           5   20            5          85            7              44
#
#    Sleep_Hours  Internet_Usage  Marks
# 0            9               6     54
# 1            4               8     89
# 2            9               5     36
# 3            6               6     59
# 4            8               1     47
#      Student_ID  Age  Study_Hours  Attendance  Assignments  Previous_Marks  \
# 995         996   22            9          81            1              44
# 996         997   18            1          71            1              99
# 997         998   21            4          83            6              95
# 998         999   25           10          99            2              85
# 999        1000   20            6          97            8              89
#
#      Sleep_Hours  Internet_Usage  Marks
# 995            8               7     85
# 996            4               7     73
# 997            9               1     38
# 998            5               7     37
# 999            8               2     98
# (1000, 9)
# Index(['Student_ID', 'Age', 'Study_Hours', 'Attendance', 'Assignments',
#        'Previous_Marks', 'Sleep_Hours', 'Internet_Usage', 'Marks'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      1000 non-null   int64
#  1   Age             1000 non-null   int32
#  2   Study_Hours     1000 non-null   int32
#  3   Attendance      1000 non-null   int32
#  4   Assignments     1000 non-null   int32
#  5   Previous_Marks  1000 non-null   int32
#  6   Sleep_Hours     1000 non-null   int32
#  7   Internet_Usage  1000 non-null   int32
#  8   Marks           1000 non-null   int32
# dtypes: int32(8), int64(1)
# memory usage: 39.2 KB
# None
#         Student_ID        Age  Study_Hours   Attendance  Assignments  \
# count  1000.000000  1000.0000  1000.000000  1000.000000  1000.000000
# mean    500.500000    21.4980     5.395000    79.830000     5.396000
# std     288.819436     2.3081     2.912638    11.786604     2.846979
# min       1.000000    18.0000     1.000000    60.000000     1.000000
# 25%     250.750000    19.7500     3.000000    70.000000     3.000000
# 50%     500.500000    21.0000     5.000000    80.000000     5.000000
# 75%     750.250000    24.0000     8.000000    90.000000     8.000000
# max    1000.000000    25.0000    10.000000   100.000000    10.000000
#
#        Previous_Marks  Sleep_Hours  Internet_Usage        Marks
# count     1000.000000  1000.000000     1000.000000  1000.000000
# mean        70.650000     6.573000        4.507000    67.886000
# std         18.098814     1.689238        2.250114    19.059913
# min         40.000000     4.000000        1.000000    35.000000
# 25%         55.000000     5.000000        3.000000    51.000000
# 50%         71.000000     7.000000        5.000000    68.000000
# 75%         87.000000     8.000000        6.000000    85.000000
# max        100.000000     9.000000        8.000000   100.000000

# %%
import numpy as np
arr = df.to_numpy()
print(arr)
# Out:
# [[   1   24    6 ...    9    6   54]
#  [   2   21    1 ...    4    8   89]
#  [   3   22    9 ...    9    5   36]
#  ...
#  [ 998   21    4 ...    9    1   38]
#  [ 999   25   10 ...    5    7   37]
#  [1000   20    6 ...    8    2   98]]

# %%
print(arr[4])
# Out:
# [ 5 20  5 85  7 44  8  1 47]

# %%
print(arr[-1])
# Out:
# [1000   20    6   97    8   89    8    2   98]

# %%
print(arr[0][8])
print(arr[0,8])
print(arr[9,3])
# Out:
# 54
# 54
# 62

# %%
print(arr[:10])
# Out:
# [[ 1 24  6 98 10 84  9  6 54]
#  [ 2 21  1 61  3 80  4  8 89]
#  [ 3 22  9 97  3 68  9  5 36]
#  [ 4 24  1 98  1 43  6  6 59]
#  [ 5 20  5 85  7 44  8  1 47]
#  [ 6 25  4 74  5 50  8  4 92]
#  [ 7 22  3 93  4 95  9  2 98]
#  [ 8 22  6 99 10 90  5  3 93]
#  [ 9 24  2 70  4 60  5  3 94]
#  [10 19  3 62  4 74  6  1 96]]

# %%
print(arr[-10:])
# Out:
# [[ 991   19    2   61   10  100    8    5   82]
#  [ 992   21    1   69    9   60    5    6   53]
#  [ 993   19    2   93    9   71    7    2   43]
#  [ 994   21    1   75    5   74    5    3   98]
#  [ 995   21    1   98   10   54    4    5   88]
#  [ 996   22    9   81    1   44    8    7   85]
#  [ 997   18    1   71    1   99    4    7   73]
#  [ 998   21    4   83    6   95    9    1   38]
#  [ 999   25   10   99    2   85    5    7   37]
#  [1000   20    6   97    8   89    8    2   98]]

# %%
print(arr[:,2])
# Out:
# [ 6  1  9  1  5  4  3  6  2  3  5  9  2 10  8  2  5  7  8  1  6  1  2  1
#   5 10  9  6  1  1  2  9  3  1  5  7  6  1  5  5  6  3  5  7  5  5  5 10
#  10  3  1  5  9  1  3  4  1  1  8  2  8  7 10 10  2  6  6  3  2  1  6  5
#   9  1  7  5  5  2  3  7  6  2  6  2  2  2  3  2  4  9  6  1  8  7 10  3
#   1  5  4 10  8  1 10  1  4  8  5  2  6  5  2  3  9  7  7  6  8  4  8  4
#   8  9  3  3  2 10  3  3  5  5  2 10  6  5  6  1  5  9 10  2  1 10  9 10
#   9  9  6  8  1 10  4  1  8  1  3  4  8  6 10  7  8  2 10  8  3  7  3  7
#   2 10  6  3  3  9  7  5 10  7  9  1  7  6 10  9  1  4  9  4 10  3  9  2
#   4  6  2  8  8  1  3 10  9  5  6  4 10  2  8  6  5  9  1  5  6  5  6  6
#   7  4  8  7  9  7  3  3  8  5  4  8  6  2  4  4  6  6  1  8  6  3  9  2
#   8 10  3  5  6 10  6  4  3  4  1  4  1  1 10  6  5  4  3  1  6  2  8 10
#   5  7 10  2  8  2  4  1  5  9  1  9  8  6  7  3  1  5  2  5  8  9  2  3
#   3  1  8  6  8  9  5  3  5  5  5  3 10  4  9 10  9  2  8  8  7  8  3  6
#   1  7  1  9  1  1  7  2  5  8  8  3  7  3  6  6  3  7  3  8 10  4  1  4
#   7  4  6  9  1  5  7  1  4  6  2 10  5 10  1  6  6  4  8  4  8  8  5  4
#   2  3  3  4  4 10  5  4 10  8  6  6  8  7 10 10  8  2  9  1  8  4  4  5
#   8  5  8 10  1 10  9  6  3  8  9  6  7  1  5  5 10  4  6  7  9  1  6  7
#   3  8  5  9  5  9 10  4  9  5 10  9  3  4  9 10  6  2  7  2  2  1  3  6
#   8  9  7  4  6  5  8  1  1  6 10  2  5  1  7  1  4  9  1  4  6  6  8  1
#   7  1  7  3  8  3  1  8  3  2  1  3  2  2  6  1  2  6  3  4  1  8  7  7
#   3 10 10  3  2  1  7  7  2  7  8  1  9  7  3  8  7  8  6  9  5  3  3  1
#   8  2  3  8  8  4  4  5  6  5  7  2  7 10  7  1  7  5  3  3  4  2  2  1
#   5  4 10  2  3  7  7  4  5  5  6  9  2  5  3  4 10  6  8  1 10  8  7  1
#   2  3  1  9  8  2  9  7  9  6  6  4 10 10  2  7  5  6  2  5 10  4  9  6
#   2  1  5  9  6 10  7  5 10  6  5  9  6  8  2  9  5  7 10  1 10  5 10  2
#   6  1  3  5  4  3 10  5  8  4  1  7  8  3  6  2  7  8  6  6  5  8  1 10
#   4  4  3  3  4  1  2  9 10  2  5  9  9  8  1  1  9  8 10  9  7  3  3  2
#   5  3  6  2  3  5  1  1 10  9  7  1  8  3  8  5  1  7  5  6  6  8  9  2
#   9 10  9 10 10  7  1  7 10  5  6 10  7  5  7  9  3  8  2  7  2  4  7  3
#   2 10  7  1  8  3  2  3  5  8 10  7  7  7  8  1  4  6  9  2  1 10  2  7
#   3 10  2  7  2  3  7  4  1  5  9  8  9 10  9  7  4  5  1  1  3  8  2  4
#   2  5  9  1  5  9  1  9  8  4 10  5  5  6  7  8  8  2  9  7  4  4  8  4
#   6  5  3 10  2  9 10  9  1 10  3  8  6  5  5  6  7  1  9  3  4 10  1 10
#   3  2  2  1  8  3  3  6  8  9  9  4  5  2  9  8  3  9  3  9  2 10  9  8
#   9  5  2  8  6  8  5 10  2  6  5  5  1  2  8  3 10  3  8  8  2  8  1  6
#   8  3  8  1  9  9  5 10  4  6  7  5 10  9  3  7 10 10  5  7  2  4  2  7
#   2  1  9  1  8  2  8  3  6  3  7 10  9  2  5  6  4  4  4  2  4  1  6  1
#  10  6  1  6 10  8  2  2  4  3  4  7  1  6  3 10  7 10  2  2  4  1  3  9
#   7  7  4  2  4  6  3  1  8  5  5  4  6  3  9  5  3  1 10  6  2  3  1  9
#   8  2  8  9  1  5  8  2  4  7  3  5  8 10  3  4  9  7  1  4  4  9  6  9
#   6  6  5  5  2  8  8  1  8  5  2  2  6  9  1  6  9  8  6  3  8  9  1  9
#   6  6  4  1 10  8  2  1  2  1  1  9  1  4 10  6]

# %%
print(np.mean(arr[:,2]))
print(np.median(arr[:,2]))
from scipy import stats
print(stats.mode(arr[:,2]))
# Out:
# 5.395
# 5.0
# ModeResult(mode=np.int64(1), count=np.int64(117))

# %% [markdown]
# # Task
# Probability,
# vectors,
# class and object,
# correlation,
# feature intution,
# conditions,
# loops,
# matrix.

# %% [markdown]
# # Vectorization
# # 20.07.2026

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-3.0.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.5.1-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in .\.venv\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.3-cp313-cp313-win_amd64.whl (9.8 MB)
# Using cached numpy-2.5.1-cp313-cp313-win_amd64.whl (12.4 MB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, numpy, pandas
#
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed numpy-2.5.1 pandas-3.0.3 tzdata-2026.3

# %%
! pip install numpy
# Out:
# Requirement already satisfied: numpy in .\.venv\.venv\Lib\site-packages (2.5.1)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("student_performance_1000.csv")
print(df.head)
# Out:
# <bound method NDFrame.head of      Student_ID  Age  Study_Hours  Attendance  Assignments  Previous_Marks  \
# 0             1   24            6          98           10              84
# 1             2   21            1          61            3              80
# 2             3   22            9          97            3              68
# 3             4   24            1          98            1              43
# 4             5   20            5          85            7              44
# ..          ...  ...          ...         ...          ...             ...
# 995         996   22            9          81            1              44
# 996         997   18            1          71            1              99
# 997         998   21            4          83            6              95
# 998         999   25           10          99            2              85
# 999        1000   20            6          97            8              89
#
#      Sleep_Hours  Internet_Usage  Marks
# 0              9               6     54
# 1              4               8     89
# 2              9               5     36
# 3              6               6     59
# 4              8               1     47
# ..           ...             ...    ...
# 995            8               7     85
# 996            4               7     73
# 997            9               1     38
# 998            5               7     37
# 999            8               2     98
#
# [1000 rows x 9 columns]>

# %%
marks = df['Marks'].to_numpy()
attendance = df['Attendance'].to_numpy()
study_hours = df['Study_Hours'].to_numpy()
Previous = df['Previous_Marks'].to_numpy()

print(type(marks))
# Out:
# <class 'numpy.ndarray'>

# %%
marks_list = marks.tolist()
for i in range(len(marks_list)):
    marks_list[i] +=5
print(marks_list[:10])
print(marks[:10])
# Out:
# [59, 94, 41, 64, 52, 97, 103, 98, 99, 101]
# [54 89 36 59 47 92 98 93 94 96]

# %% [markdown]
# Task
# Do it for numpy

# %%
study_hours = np.multiply(study_hours,marks)
print("Study Hours:",study_hours[:10])
print("Marks:",marks[:10])
# Out:
# Study Hours: [324  89 324  59 235 368 294 558 188 288]
# Marks: [54 89 36 59 47 92 98 93 94 96]

# %% [markdown]
# # UNIVERSAL FUNCTION
# # 21.07.2026

# %%
print(np.sqrt(marks[:10]))
print(np.log(marks[:10]))
print(np.exp(study_hours[:10]))
print(np.sin(study_hours[:10]))
# Out:
# [7.34846923 9.43398113 6.         7.68114575 6.8556546  9.59166305
#  9.89949494 9.64365076 9.69535971 9.79795897]
# [3.98898405 4.48863637 3.58351894 4.07753744 3.8501476  4.52178858
#  4.58496748 4.53259949 4.54329478 4.56434819]
# [4.03428793e+02 2.71828183e+00 8.10308393e+03 2.71828183e+00
#  1.48413159e+02 5.45981500e+01 2.00855369e+01 4.03428793e+02
#  7.38905610e+00 2.00855369e+01]
# [-0.2794155   0.84147098  0.41211849  0.84147098 -0.95892427 -0.7568025
#   0.14112001 -0.2794155   0.90929743  0.14112001]

# %% [markdown]
# # Pandas / series / Data frame

# %%
import pandas as pd
students = pd.Series(['priya','vib','raja','sneha'])
print(students)
# Out:
# 0    priya
# 1      vib
# 2     raja
# 3    sneha
# dtype: str

# %%
import pandas as pd
students = pd.Series(['priya','vib','raja','sneha'],
index = [101,102,103,104])
print(students)
print(students[[101,104]])
# Out:
# 101    priya
# 102      vib
# 103     raja
# 104    sneha
# dtype: str
# 101    priya
# 104    sneha
# dtype: str

# %%
data = {
"ID":[101,102,103,104],
"Name":["Priya","Rahul","Sneha","sss"],
"Age":[22,21,23,55],
"Marks":[85,90,88,88]
}

df = pd.DataFrame(data)
print(data)
print(df)
# Out:
# {'ID': [101, 102, 103, 104], 'Name': ['Priya', 'Rahul', 'Sneha', 'sss'], 'Age': [22, 21, 23, 55], 'Marks': [85, 90, 88, 88]}
#     ID   Name  Age  Marks
# 0  101  Priya   22     85
# 1  102  Rahul   21     90
# 2  103  Sneha   23     88
# 3  104    sss   55     88

# %%
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df.describe)
# Out:
# (4, 4)
# Index(['ID', 'Name', 'Age', 'Marks'], dtype='str')
# ID       int64
# Name       str
# Age      int64
# Marks    int64
# dtype: object
# <bound method NDFrame.describe of     ID   Name  Age  Marks
# 0  101  Priya   22     85
# 1  102  Rahul   21     90
# 2  103  Sneha   23     88
# 3  104    sss   55     88>

# %% [markdown]
# # Task
# Create employee database with series and Dataframe
